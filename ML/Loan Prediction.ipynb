# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Dataset

# %%
df = pd.read_csv("train.csv")
df.head(25)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# 13  LP001029    Male      No          0      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# 15  LP001032    Male      No          0      Graduate            No
# 16  LP001034    Male      No          1  Not Graduate            No
# 17  LP001036  Female      No          0      Graduate            No
# 18  LP001038    Male     Yes          0  Not Graduate            No
# 19  LP001041    Male     Yes          0      Graduate           NaN
# 20  LP001043    Male     Yes          0  Not Graduate            No
# 21  LP001046    Male     Yes          1      Graduate            No
# 22  LP001047    Male     Yes          0  Not Graduate            No
# 23  LP001050     NaN     Yes          2  Not Graduate            No
# 24  LP001052    Male     Yes          1      Graduate           NaN
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# 3              2583             2358.0       120.0             360.0
# 4              6000                0.0       141.0             360.0
# 5              5417             4196.0       267.0             360.0
# 6              2333             1516.0        95.0             360.0
# 7              3036             2504.0       158.0             360.0
# 8              4006             1526.0       168.0             360.0
# 9             12841            10968.0       349.0             360.0
# 10             3200              700.0        70.0             360.0
# 11             2500             1840.0       109.0             360.0
# 12             3073             8106.0       200.0             360.0
# 13             1853             2840.0       114.0             360.0
# 14             1299             1086.0        17.0             120.0
# 15             4950                0.0       125.0             360.0
# 16             3596                0.0       100.0             240.0
# 17             3510                0.0        76.0             360.0
# 18             4887                0.0       133.0             360.0
# 19             2600             3500.0       115.0               NaN
# 20             7660                0.0       104.0             360.0
# 21             5955             5625.0       315.0             360.0
# 22             2600             1911.0       116.0             360.0
# 23             3365             1917.0       112.0             360.0
# 24             3717             2925.0       151.0             360.0
#
#     Credit_History Property_Area Loan_Status
# 0              1.0         Urban           Y
# 1              1.0         Rural           N
# 2              1.0         Urban           Y
# 3              1.0         Urban           Y
# 4              1.0         Urban           Y
# 5              1.0         Urban           Y
# 6              1.0         Urban           Y
# 7              0.0     Semiurban           N
# 8              1.0         Urban           Y
# 9              1.0     Semiurban           N
# 10             1.0         Urban           Y
# 11             1.0         Urban           Y
# 12             1.0         Urban           Y
# 13             1.0         Rural           N
# 14             1.0         Urban           Y
# 15             1.0         Urban           Y
# 16             NaN         Urban           Y
# 17             0.0         Urban           N
# 18             1.0         Rural           N
# 19             1.0         Urban           Y
# 20             0.0         Urban           N
# 21             1.0         Urban           Y
# 22             0.0     Semiurban           N
# 23             0.0         Rural           N
# 24             NaN     Semiurban           N

# %%
df.tail(25)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 589  LP002926    Male     Yes          2      Graduate           Yes
# 590  LP002928    Male     Yes          0      Graduate            No
# 591  LP002931    Male     Yes          2      Graduate           Yes
# 592  LP002933     NaN      No         3+      Graduate           Yes
# 593  LP002936    Male     Yes          0      Graduate            No
# 594  LP002938    Male     Yes          0      Graduate           Yes
# 595  LP002940    Male      No          0  Not Graduate            No
# 596  LP002941    Male     Yes          2  Not Graduate           Yes
# 597  LP002943    Male      No        NaN      Graduate            No
# 598  LP002945    Male     Yes          0      Graduate           Yes
# 599  LP002948    Male     Yes          2      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 601  LP002950    Male     Yes          0  Not Graduate           NaN
# 602  LP002953    Male     Yes         3+      Graduate            No
# 603  LP002958    Male      No          0      Graduate            No
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 589             2726                0.0       106.0             360.0
# 590             3000             3416.0        56.0             180.0
# 591             6000                0.0       205.0             240.0
# 592             9357                0.0       292.0             360.0
# 593             3859             3300.0       142.0             180.0
# 594            16120                0.0       260.0             360.0
# 595             3833                0.0       110.0             360.0
# 596             6383             1000.0       187.0             360.0
# 597             2987                0.0        88.0             360.0
# 598             9963                0.0       180.0             360.0
# 599             5780                0.0       192.0             360.0
# 600              416            41667.0       350.0             180.0
# 601             2894             2792.0       155.0             360.0
# 602             5703                0.0       128.0             360.0
# 603             3676             4301.0       172.0             360.0
# 604            12000                0.0       496.0             360.0
# 605             2400             3800.0         NaN             180.0
# 606             3400             2500.0       173.0             360.0
# 607             3987             1411.0       157.0             360.0
# 608             3232             1950.0       108.0             360.0
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 589             0.0     Semiurban           N
# 590             1.0     Semiurban           Y
# 591             1.0     Semiurban           N
# 592             1.0     Semiurban           Y
# 593             1.0         Rural           Y
# 594             1.0         Urban           Y
# 595             1.0         Rural           Y
# 596             1.0         Rural           N
# 597             0.0     Semiurban           N
# 598             1.0         Rural           Y
# 599             1.0         Urban           Y
# 600             NaN         Urban           N
# 601             1.0         Rural           Y
# 602             1.0         Urban           Y
# 603             1.0         Rural           Y
# 604             1.0     Semiurban           Y
# 605             1.0         Urban           N
# 606             1.0     Semiurban           Y
# 607             1.0         Rural           Y
# 608             1.0         Rural           Y
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
print ("Shape Of The Data Set: ", df.shape)
# Out:
# Shape Of The Data Set:  (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df[['ApplicantIncome', 'LoanAmount']]
# Out:
#      ApplicantIncome  LoanAmount
# 0               5849         NaN
# 1               4583       128.0
# 2               3000        66.0
# 3               2583       120.0
# 4               6000       141.0
# ..               ...         ...
# 609             2900        71.0
# 610             4106        40.0
# 611             8072       253.0
# 612             7583       187.0
# 613             4583       133.0
#
# [614 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
import seaborn as sns
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.countplot(df.Dependents)
# Out:
# <Axes: xlabel='count', ylabel='Dependents'>

# %%
sns.countplot(df.Married)
# Out:
# <Axes: xlabel='count', ylabel='Married'>

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
sns.distplot(df.LoanAmount)
# Out:
# /tmp/ipykernel_18848/411373110.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.LoanAmount)
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
sns.distplot(df.Credit_History)
# Out:
# /tmp/ipykernel_18848/1707142252.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Credit_History)
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %%
df.head(25)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate            No
# 12  LP001028    Male     Yes          2      Graduate            No
# 13  LP001029    Male      No          0      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# 15  LP001032    Male      No          0      Graduate            No
# 16  LP001034    Male      No          1  Not Graduate            No
# 17  LP001036  Female      No          0      Graduate            No
# 18  LP001038    Male     Yes          0  Not Graduate            No
# 19  LP001041    Male     Yes          0      Graduate            No
# 20  LP001043    Male     Yes          0  Not Graduate            No
# 21  LP001046    Male     Yes          1      Graduate            No
# 22  LP001047    Male     Yes          0  Not Graduate            No
# 23  LP001050    Male     Yes          2  Not Graduate            No
# 24  LP001052    Male     Yes          1      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0  146.412162             360.0
# 1              4583             1508.0  128.000000             360.0
# 2              3000                0.0   66.000000             360.0
# 3              2583             2358.0  120.000000             360.0
# 4              6000                0.0  141.000000             360.0
# 5              5417             4196.0  267.000000             360.0
# 6              2333             1516.0   95.000000             360.0
# 7              3036             2504.0  158.000000             360.0
# 8              4006             1526.0  168.000000             360.0
# 9             12841            10968.0  349.000000             360.0
# 10             3200              700.0   70.000000             360.0
# 11             2500             1840.0  109.000000             360.0
# 12             3073             8106.0  200.000000             360.0
# 13             1853             2840.0  114.000000             360.0
# 14             1299             1086.0   17.000000             120.0
# 15             4950                0.0  125.000000             360.0
# 16             3596                0.0  100.000000             240.0
# 17             3510                0.0   76.000000             360.0
# 18             4887                0.0  133.000000             360.0
# 19             2600             3500.0  115.000000             342.0
# 20             7660                0.0  104.000000             360.0
# 21             5955             5625.0  315.000000             360.0
# 22             2600             1911.0  116.000000             360.0
# 23             3365             1917.0  112.000000             360.0
# 24             3717             2925.0  151.000000             360.0
#
#     Credit_History Property_Area Loan_Status
# 0         1.000000         Urban           Y
# 1         1.000000         Rural           N
# 2         1.000000         Urban           Y
# 3         1.000000         Urban           Y
# 4         1.000000         Urban           Y
# 5         1.000000         Urban           Y
# 6         1.000000         Urban           Y
# 7         0.000000     Semiurban           N
# 8         1.000000         Urban           Y
# 9         1.000000     Semiurban           N
# 10        1.000000         Urban           Y
# 11        1.000000         Urban           Y
# 12        1.000000         Urban           Y
# 13        1.000000         Rural           N
# 14        1.000000         Urban           Y
# 15        1.000000         Urban           Y
# 16        0.842199         Urban           Y
# 17        0.000000         Urban           N
# 18        1.000000         Rural           N
# 19        1.000000         Urban           Y
# 20        0.000000         Urban           N
# 21        1.000000         Urban           Y
# 22        0.000000     Semiurban           N
# 23        0.000000         Rural           N
# 24        0.842199     Semiurban           N

# %%
df['Total_income'] = df['ApplicantIncome']+df['CoapplicantIncome']

# %%
df.head(25)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate            No
# 12  LP001028    Male     Yes          2      Graduate            No
# 13  LP001029    Male      No          0      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# 15  LP001032    Male      No          0      Graduate            No
# 16  LP001034    Male      No          1  Not Graduate            No
# 17  LP001036  Female      No          0      Graduate            No
# 18  LP001038    Male     Yes          0  Not Graduate            No
# 19  LP001041    Male     Yes          0      Graduate            No
# 20  LP001043    Male     Yes          0  Not Graduate            No
# 21  LP001046    Male     Yes          1      Graduate            No
# 22  LP001047    Male     Yes          0  Not Graduate            No
# 23  LP001050    Male     Yes          2  Not Graduate            No
# 24  LP001052    Male     Yes          1      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0  146.412162             360.0
# 1              4583             1508.0  128.000000             360.0
# 2              3000                0.0   66.000000             360.0
# 3              2583             2358.0  120.000000             360.0
# 4              6000                0.0  141.000000             360.0
# 5              5417             4196.0  267.000000             360.0
# 6              2333             1516.0   95.000000             360.0
# 7              3036             2504.0  158.000000             360.0
# 8              4006             1526.0  168.000000             360.0
# 9             12841            10968.0  349.000000             360.0
# 10             3200              700.0   70.000000             360.0
# 11             2500             1840.0  109.000000             360.0
# 12             3073             8106.0  200.000000             360.0
# 13             1853             2840.0  114.000000             360.0
# 14             1299             1086.0   17.000000             120.0
# 15             4950                0.0  125.000000             360.0
# 16             3596                0.0  100.000000             240.0
# 17             3510                0.0   76.000000             360.0
# 18             4887                0.0  133.000000             360.0
# 19             2600             3500.0  115.000000             342.0
# 20             7660                0.0  104.000000             360.0
# 21             5955             5625.0  315.000000             360.0
# 22             2600             1911.0  116.000000             360.0
# 23             3365             1917.0  112.000000             360.0
# 24             3717             2925.0  151.000000             360.0
#
#     Credit_History Property_Area Loan_Status  Total_income
# 0         1.000000         Urban           Y        5849.0
# 1         1.000000         Rural           N        6091.0
# 2         1.000000         Urban           Y        3000.0
# 3         1.000000         Urban           Y        4941.0
# 4         1.000000         Urban           Y        6000.0
# 5         1.000000         Urban           Y        9613.0
# 6         1.000000         Urban           Y        3849.0
# 7         0.000000     Semiurban           N        5540.0
# 8         1.000000         Urban           Y        5532.0
# 9         1.000000     Semiurban           N       23809.0
# 10        1.000000         Urban           Y        3900.0
# 11        1.000000         Urban           Y        4340.0
# 12        1.000000         Urban           Y       11179.0
# 13        1.000000         Rural           N        4693.0
# 14        1.000000         Urban           Y        2385.0
# 15        1.000000         Urban           Y        4950.0
# 16        0.842199         Urban           Y        3596.0
# 17        0.000000         Urban           N        3510.0
# 18        1.000000         Rural           N        4887.0
# 19        1.000000         Urban           Y        6100.0
# 20        0.000000         Urban           N        7660.0
# 21        1.000000         Urban           Y       11580.0
# 22        0.000000     Semiurban           N        4511.0
# 23        0.000000         Rural           N        5282.0
# 24        0.842199     Semiurban           N        6642.0

# %%
print ("Loan Status : Yes/No",end="")
df.Loan_Status.value_counts()
# Out:
# Loan Status : Yes/No
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
print ("Education:")
df.Education.value_counts()
# Out:
# Education:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# Total_income         0
# dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
import pandas as pd

# Separate features and target variable
X = df.drop("Loan_Status", axis=1)  # Features
y = df["Loan_Status"]  # Target variable

# Instantiate the RandomOverSampler
oversampler = RandomOverSampler(random_state=42)

# Apply oversampling
X_resampled, y_resampled = oversampler.fit_resample(X, y)

# Create a new DataFrame with the resampled data
resampled_df = pd.concat([X_resampled, y_resampled], axis=1)

# Check the class distribution after oversampling
print(resampled_df["Loan_Status"].value_counts())
# Out:
# Loan_Status
# Y    422
# N    422
# Name: count, dtype: int64

# %%
resampled_df.head(25)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate            No
# 12  LP001028    Male     Yes          2      Graduate            No
# 13  LP001029    Male      No          0      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# 15  LP001032    Male      No          0      Graduate            No
# 16  LP001034    Male      No          1  Not Graduate            No
# 17  LP001036  Female      No          0      Graduate            No
# 18  LP001038    Male     Yes          0  Not Graduate            No
# 19  LP001041    Male     Yes          0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0  146.412162             360.0
# 1              4583             1508.0  128.000000             360.0
# 2              3000                0.0   66.000000             360.0
# 3              2583             2358.0  120.000000             360.0
# 4              6000                0.0  141.000000             360.0
# 5              5417             4196.0  267.000000             360.0
# 6              2333             1516.0   95.000000             360.0
# 7              3036             2504.0  158.000000             360.0
# 8              4006             1526.0  168.000000             360.0
# 9             12841            10968.0  349.000000             360.0
# 10             3200              700.0   70.000000             360.0
# 11             2500             1840.0  109.000000             360.0
# 12             3073             8106.0  200.000000             360.0
# 13             1853             2840.0  114.000000             360.0
# 14             1299             1086.0   17.000000             120.0
# 15             4950                0.0  125.000000             360.0
# 16             3596                0.0  100.000000             240.0
# 17             3510                0.0   76.000000             360.0
# 18             4887                0.0  133.000000             360.0
# 19             2600             3500.0  115.000000             342.0
#
#     Credit_History Property_Area  Total_income Loan_Status
# 0         1.000000         Urban        5849.0           Y
# 1         1.000000         Rural        6091.0           N
# 2         1.000000         Urban        3000.0           Y
# 3         1.000000         Urban        4941.0           Y
# 4         1.000000         Urban        6000.0           Y
# 5         1.000000         Urban        9613.0           Y
# 6         1.000000         Urban        3849.0           Y
# 7         0.000000     Semiurban        5540.0           N
# 8         1.000000         Urban        5532.0           Y
# 9         1.000000     Semiurban       23809.0           N
# 10        1.000000         Urban        3900.0           Y
# 11        1.000000         Urban        4340.0           Y
# 12        1.000000         Urban       11179.0           Y
# 13        1.000000         Rural        4693.0           N
# 14        1.000000         Urban        2385.0           Y
# 15        1.000000         Urban        4950.0           Y
# 16        0.842199         Urban        3596.0           Y
# 17        0.000000         Urban        3510.0           N
# 18        1.000000         Rural        4887.0           N
# 19        1.000000         Urban        6100.0           Y

# %%
print ("Sample Data Shape: ", 
resampled_df.shape)
# Out:
# Sample Data Shape:  (844, 14)

# %%
resampled_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Total_income         0
# Loan_Status          0
# dtype: int64

# %%
d1 = pd.get_dummies(resampled_df['Gender'], drop_first= True)
d2 = pd.get_dummies(resampled_df['Married'], drop_first= True)
d3 = pd.get_dummies(resampled_df['Dependents'], drop_first= True)
d4 = pd.get_dummies(resampled_df['Education'], drop_first= True)
d5 = pd.get_dummies(resampled_df['Self_Employed'], drop_first= True)
d6 = pd.get_dummies(resampled_df['Property_Area'], drop_first= True)

# %%
resampled_df = pd.concat([resampled_df, d1, d2, d3, d4, d5, d6], axis = 1)

# %%
cols = ['Loan_ID','Gender', 'Married', "Dependents", "Education", "Self_Employed", 'Property_Area','ApplicantIncome','CoapplicantIncome']
df_final = resampled_df.drop(columns=cols, axis=1)

# %%
df_final
# Out:
#      LoanAmount  Loan_Amount_Term  Credit_History  Total_income Loan_Status  \
# 0    146.412162             360.0        1.000000        5849.0           Y
# 1    128.000000             360.0        1.000000        6091.0           N
# 2     66.000000             360.0        1.000000        3000.0           Y
# 3    120.000000             360.0        1.000000        4941.0           Y
# 4    141.000000             360.0        1.000000        6000.0           Y
# ..          ...               ...             ...           ...         ...
# 839  146.412162             180.0        1.000000        3992.0           N
# 840   61.000000             360.0        0.842199        1880.0           N
# 841  146.000000             360.0        0.000000        4704.0           N
# 842   45.000000             180.0        0.000000        2889.0           N
# 843   98.000000             360.0        0.000000        4166.0           N
#
#      Male    Yes      1      2     3+  Not Graduate    Yes  Semiurban  Urban
# 0    True  False  False  False  False         False  False      False   True
# 1    True   True   True  False  False         False  False      False  False
# 2    True   True  False  False  False         False   True      False   True
# 3    True   True  False  False  False          True  False      False   True
# 4    True  False  False  False  False         False  False      False   True
# ..    ...    ...    ...    ...    ...           ...    ...        ...    ...
# 839  True   True  False  False   True          True  False      False   True
# 840  True   True   True  False  False         False  False      False  False
# 841  True   True   True  False  False         False  False      False  False
# 842  True   True  False   True  False          True  False      False   True
# 843  True  False  False  False  False         False  False       True  False
#
# [844 rows x 14 columns]

# %%
print ("Final Data Shape: ",df_final.shape
)
# Out:
# Final Data Shape:  (844, 14)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 844 entries, 0 to 843
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LoanAmount        844 non-null    float64
#  1   Loan_Amount_Term  844 non-null    float64
#  2   Credit_History    844 non-null    float64
#  3   Total_income      844 non-null    float64
#  4   Loan_Status       844 non-null    object
#  5   Male              844 non-null    bool
#  6   Yes               844 non-null    bool
#  7   1                 844 non-null    bool
#  8   2                 844 non-null    bool
#  9   3+                844 non-null    bool
#  10  Not Graduate      844 non-null    bool
#  11  Yes               844 non-null    bool
#  12  Semiurban         844 non-null    bool
#  13  Urban             844 non-null    bool
# dtypes: bool(9), float64(4), object(1)
# memory usage: 40.5+ KB

# %%
df_final.tail()
# Out:
#      LoanAmount  Loan_Amount_Term  Credit_History  Total_income Loan_Status  \
# 839  146.412162             180.0        1.000000        3992.0           N
# 840   61.000000             360.0        0.842199        1880.0           N
# 841  146.000000             360.0        0.000000        4704.0           N
# 842   45.000000             180.0        0.000000        2889.0           N
# 843   98.000000             360.0        0.000000        4166.0           N
#
#      Male    Yes      1      2     3+  Not Graduate    Yes  Semiurban  Urban
# 839  True   True  False  False   True          True  False      False   True
# 840  True   True   True  False  False         False  False      False  False
# 841  True   True   True  False  False         False  False      False  False
# 842  True   True  False   True  False          True  False      False   True
# 843  True  False  False  False  False         False  False       True  False

# %%
df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome'])

# %%
sns.distplot(df.ApplicantIncomeLog)
# Out:
# /tmp/ipykernel_18848/3240495108.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.ApplicantIncomeLog)
# <Axes: xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status  Total_income  ApplicantIncomeLog
# 0             1.0         Urban           Y        5849.0            8.674026
# 1             1.0         Rural           N        6091.0            8.430109
# 2             1.0         Urban           Y        3000.0            8.006368
# 3             1.0         Urban           Y        4941.0            7.856707
# 4             1.0         Urban           Y        6000.0            8.699515

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  146.412162        342.000000
# std        6109.041673        2926.248369   84.037468         64.372489
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  129.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History  Total_income  ApplicantIncomeLog
# count      614.000000    614.000000          614.000000
# mean         0.842199   7024.705081            8.341213
# std          0.349681   6458.663872            0.645263
# min          0.000000   1442.000000            5.010635
# 25%          1.000000   4166.000000            7.964677
# 50%          1.000000   5416.500000            8.246040
# 75%          1.000000   7521.750000            8.664750
# max          1.000000  81000.000000           11.302204

# %%
test = pd.read_csv("test.csv")
# filling numerical missing data
test['LoanAmount']=test['LoanAmount'].fillna(test['LoanAmount'].mean())
test['Loan_Amount_Term']=test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mean())
test['Credit_History']=test['Credit_History'].fillna(test['Credit_History'].mean())

# filling categorical missing data
test['Gender']=test['Gender'].fillna(test['Gender'].mode()[0])
test['Married']=test['Married'].fillna(test['Married'].mode()[0])
test['Dependents']=test['Dependents'].fillna(test['Dependents'].mode()[0])
test['Self_Employed']=test['Self_Employed'].fillna(test['Self_Employed'].mode()[0])

test['Total_income'] = test['ApplicantIncome']+test['CoapplicantIncome']

# %%
t1 = pd.get_dummies(test['Gender'], drop_first= True)
t2 = pd.get_dummies(test['Married'], drop_first= True)
t3 = pd.get_dummies(test['Dependents'], drop_first= True)
t4 = pd.get_dummies(test['Education'], drop_first= True)
t5 = pd.get_dummies(test['Self_Employed'], drop_first= True)
t6 = pd.get_dummies(test['Property_Area'], drop_first= True)

# %%
df1 = pd.concat([test, t1, t2, t3, t4, t5, t6], axis = 1)
test=df1

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  ...  \
# 0             5720                  0       110.0             360.0  ...
# 1             3076               1500       126.0             360.0  ...
# 2             5000               1800       208.0             360.0  ...
# 3             2340               2546       100.0             360.0  ...
# 4             3276                  0        78.0             360.0  ...
#
#    Total_income  Male    Yes      1      2     3+  Not Graduate    Yes  \
# 0          5720  True   True  False  False  False         False  False
# 1          4576  True   True   True  False  False         False  False
# 2          6800  True   True  False   True  False         False  False
# 3          4886  True   True  False   True  False         False  False
# 4          3276  True  False  False  False  False          True  False
#
#    Semiurban  Urban
# 0      False   True
# 1      False   True
# 2      False   True
# 3      False   True
# 4      False   True
#
# [5 rows x 22 columns]

# %%
cols = ['Loan_ID','Gender', 'Married', "Dependents", "Education", "Self_Employed", 'Property_Area','ApplicantIncome','CoapplicantIncome']
test = test.drop(columns=cols, axis=1)

# %%
test.head()
# Out:
#    LoanAmount  Loan_Amount_Term  Credit_History  Total_income  Male    Yes  \
# 0       110.0             360.0        1.000000          5720  True   True
# 1       126.0             360.0        1.000000          4576  True   True
# 2       208.0             360.0        1.000000          6800  True   True
# 3       100.0             360.0        0.825444          4886  True   True
# 4        78.0             360.0        1.000000          3276  True  False
#
#        1      2     3+  Not Graduate    Yes  Semiurban  Urban
# 0  False  False  False         False  False      False   True
# 1   True  False  False         False  False      False   True
# 2  False   True  False         False  False      False   True
# 3  False   True  False         False  False      False   True
# 4  False  False  False          True  False      False   True

# %%
df_final.head()
# Out:
#    LoanAmount  Loan_Amount_Term  Credit_History  Total_income Loan_Status  \
# 0  146.412162             360.0             1.0        5849.0           Y
# 1  128.000000             360.0             1.0        6091.0           N
# 2   66.000000             360.0             1.0        3000.0           Y
# 3  120.000000             360.0             1.0        4941.0           Y
# 4  141.000000             360.0             1.0        6000.0           Y
#
#    Male    Yes      1      2     3+  Not Graduate    Yes  Semiurban  Urban
# 0  True  False  False  False  False         False  False      False   True
# 1  True   True   True  False  False         False  False      False  False
# 2  True   True  False  False  False         False   True      False   True
# 3  True   True  False  False  False          True  False      False   True
# 4  True  False  False  False  False         False  False      False   True

# %%
x = df_final.drop(columns=['Loan_Status'], axis=1)
y = df_final['Loan_Status']

# %%
x
# Out:
#      LoanAmount  Loan_Amount_Term  Credit_History  Total_income  Male    Yes  \
# 0    146.412162             360.0        1.000000        5849.0  True  False
# 1    128.000000             360.0        1.000000        6091.0  True   True
# 2     66.000000             360.0        1.000000        3000.0  True   True
# 3    120.000000             360.0        1.000000        4941.0  True   True
# 4    141.000000             360.0        1.000000        6000.0  True  False
# ..          ...               ...             ...           ...   ...    ...
# 839  146.412162             180.0        1.000000        3992.0  True   True
# 840   61.000000             360.0        0.842199        1880.0  True   True
# 841  146.000000             360.0        0.000000        4704.0  True   True
# 842   45.000000             180.0        0.000000        2889.0  True   True
# 843   98.000000             360.0        0.000000        4166.0  True  False
#
#          1      2     3+  Not Graduate    Yes  Semiurban  Urban
# 0    False  False  False         False  False      False   True
# 1     True  False  False         False  False      False  False
# 2    False  False  False         False   True      False   True
# 3    False  False  False          True  False      False   True
# 4    False  False  False         False  False      False   True
# ..     ...    ...    ...           ...    ...        ...    ...
# 839  False  False   True          True  False      False   True
# 840   True  False  False         False  False      False  False
# 841   True  False  False         False  False      False  False
# 842  False   True  False          True  False      False   True
# 843  False  False  False         False  False       True  False
#
# [844 rows x 13 columns]

# %%
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 839    N
# 840    N
# 841    N
# 842    N
# 843    N
# Name: Loan_Status, Length: 844, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
x_train.head()
# Out:
#      LoanAmount  Loan_Amount_Term  Credit_History  Total_income   Male    Yes  \
# 425       121.0             360.0             1.0        6966.0   True   True
# 660        81.0             360.0             1.0        4606.0  False  False
# 417       239.0             360.0             1.0       21600.0   True   True
# 759        66.0             300.0             0.0        2178.0   True   True
# 90        131.0             360.0             1.0        5858.0   True   True
#
#          1      2     3+  Not Graduate    Yes  Semiurban  Urban
# 425  False  False  False         False  False      False  False
# 660   True  False  False          True  False      False  False
# 417  False   True  False         False   True      False   True
# 759   True  False  False         False   True      False  False
# 90   False  False  False         False  False       True  False

# %%
y_test.head()
# Out:
# 493    Y
# 215    Y
# 622    N
# 737    N
# 63     N
# Name: Loan_Status, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()

model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print("Accuracy is", model.score(x_test, y_test)*100)
# Out:
# Accuracy is 87.20379146919431

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score,f1_score

model2 = DecisionTreeClassifier()
model2.fit(x_train, y_train)
print("Accuracy is", model2.score(x_test, y_test)*100)
# Out:
# Accuracy is 84.83412322274881

# %%
from sklearn.linear_model import LogisticRegression

# Create and train the logistic regression model
model3 = LogisticRegression()
model3.fit(x_train, y_train)

# Evaluate the model's accuracy on the test data
accuracy = model3.score(x_test, y_test) * 100
print("Accuracy is", accuracy)
# Out:
# Accuracy is 70.61611374407583
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[98, 16],
#        [11, 86]])

# %%
import pickle
file=open("model.pkl", 'wb')
pickle.dump(model, file)

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
model
# Out:
# RandomForestClassifier()
